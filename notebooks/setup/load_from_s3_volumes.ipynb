# %%
dbutils.fs.rm("/Volumes/ecommerce_dev/bronze/raw_volume/", recurse=True)

# %%
dbutils.fs.cp(
  "s3://ecommerce-data-bucket-demini/olist_raw",
  "/Volumes/ecommerce_dev/bronze/raw_volume/",
  recurse=True
)
