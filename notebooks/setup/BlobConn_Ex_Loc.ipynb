# %%
saas = "sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2026-03-30T00:23:01Z&st=2026-03-25T16:08:01Z&spr=https&sig=g8Ar4i4hihtLhWwKc8vd0ntx3NeKWhNBcPxNvlOQH3k%3D"

# %% [markdown]
# "sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2026-03-30T00:23:01Z&st=2026-03-25T16:08:01Z&spr=https&sig=g8Ar4i4hihtLhWwKc8vd0ntx3NeKWhNBcPxNvlOQH3k%3D"

# %%
storage_account_name = "deminiprojectacc"
container_name = "raw"

sas_token = saas

# 🔥 MUST run this FIRST in the same notebook
spark.conf.set(
    "fs.azure.sas.raw.deminiprojectacc.dfs.core.windows.net",
    sas_token
)

# THEN access
display(dbutils.fs.ls("abfss://raw@deminiprojectacc.dfs.core.windows.net/"))
